# %% [markdown]
# #### Assignment -1

# %%
# 1. Who developed python programming language?

#Python programming language was developed by Guido van Rossum and was first released in 1991

# %%
# 2. Which type of Programming does Python support?

# Python supports multiple programming paradigms, such as:

# Object-Oriented Programming (OOP)
# Procedural Programming
# Functional Programming

# %%
# 3. Is Python case-sensitive when dealing with identifiers?

# Yes. Python is case-sensitive.
Name="aman"
name1="Aman"
print(Name)
print(name1)
# Out:
# aman
# Aman

# %%
# 4. What is the correct extension of a Python file?

# The correct extension is .py.
program.py

# %%
# 5. Is Python code compiled or interpreted?

# Python is generally called an interpreted language.

# More precisely, Python code is first converted into bytecode and then executed by the Python interpreter/virtual machine.

# %%
# 6. Name a few blocks of code used to define in Python language?

# Common blocks include:

# if/else blocks
# for loops
# while loops
# functions
# classes
# try/except blocks

# %%
# 7. State a character used to give single-line comments in Python?

# The # symbol is used for single-line comments.
# This is a comment
print("Hello")
# Out:
# Hello

# %%
# 8. Mention functions which can help us find the Python version we are currently working on?
import sys
print(sys.version)
# Out:
# 3.14.4 (tags/v3.14.4:23116f9, Apr  7 2026, 14:10:54) [MSC v.1944 64 bit (AMD64)]

# %%
import platform
print(platform.python_version())
# Out:
# 3.14.4

# %%
# 9. Python supports the creation of anonymous functions at runtime, using a construct called ______?

# Lambda function.
square = lambda x: x * x

# %%
# 10. What does pip stand for in Python?

# PIP is commonly expanded as “Pip Installs Packages.”

# It is Python's package-management tool used to install external packages.
# pip install pandas
# Out:
#   Cell In[8], line 6
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
# 11. Mention a few built-in functions in Python?
max()
min()
range()

# %%
# 12. What is the maximum possible length of an identifier in Python?

# Python does not impose a fixed maximum length on identifiers. In practice, 
# identifiers can be very long, although using excessively long names is not recommended.

# %%
# 13. What are the benefits of using Python?

# Main benefits:

# Easy to learn and read
# Simple syntax
# Large number of libraries
# Cross-platform
# Open-source and free

# %%
# 14. How is memory managed in Python?

# Python manages memory automatically.

# It uses:

# Private heap for Python objects
# Garbage collection to remove unused objects
# Reference counting to track objects

# %%
# 15. How to install Python on Windows and set path variables?

# Basic steps:

# Step 1: Download Python from the official Python website.

# Step 2: Run the installer.

# %%
# 16. Is indentation required in Python?

# Yes. Indentation is required in Python to define blocks of code.
